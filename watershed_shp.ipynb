# %%
import math
import os
from glob import glob
from itertools import combinations
from urllib.error import URLError

import earthpy as et
import earthpy.appeears as etapp
import geopandas as gpd
import holoviews as hv
import hvplot as hv
import hvplot.pandas
import hvplot.xarray
import numpy as np
import pandas as pd
import requests
import rioxarray as rxr
import rioxarray.merge as rxrmerge
import skfuzzy as fuzz
from skfuzzy import control as ctrl
from IPython.display import Image
import utm
import xarray as xr
import xrspatial
import warnings
import zipfile


data_dir = os.path.join(et.io.HOME, et.io.DATA_NAME, 'treebeard')
wbd_url = (
    'https://prd-tnm.s3.amazonaws.com'
    '/StagedProducts/Hydrography/WBD/HU2/Shape'
    '/WBD_10_HU2_Shape.zip')
wdb_shp_file = os.path.join(data_dir, 'WBD_10_HU2_Shape', 'Shape', 'WBDHU10.shp')

# Create the directory if it doesn't exist
os.makedirs(data_dir, exist_ok=True)

# Download the file
if not response:
    response = requests.get(wbd_url)

# %%
zip_path = os.path.join(data_dir, 'WBD_10_HU2_Shape.zip')
with open(zip_path, 'wb') as f:
    f.write(response.content)

# Extract the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(wbd_dir)

# %%
wdb_shp_file
# Out:
# '/Users/ed.chan/earth-analytics/data/treebeard/WBD_10_HU2_Shape/Shape/WBDHU10.shp'

# %%
wdb_gdf = gpd.read_file(wdb_shp_file)
left_hand_creek_gdf = wdb_gdf[wdb_gdf['huc10'] == '1019000503'].copy()

# %%
plot = left_hand_creek_gdf.hvplot(geo=True, color='blue', tiles='OSM',
                                alpha=0.3)
plot
# Out:
# :Overlay
#    .WMTS.I     :WMTS   [Longitude,Latitude]
#    .Polygons.I :Polygons   [Longitude,Latitude]

# %%
hvplot.save(plot, f'images/left_hand_creek.png')
# Out:
# WARNING:bokeh.core.validation.check:W-1005 (FIXED_SIZING_MODE): 'fixed' sizing mode requires width and height to be set: figure(id='p2648', ...)
